# %% [markdown]
# <a href="https://colab.research.google.com/github/panchambanerjee/core-llm/blob/main/A_hacker's_guide_to_Language_Models_Part_II.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # A Hacker's Guide to Language Models, A lecture by Jeremy Howard.
#
# #### Notes marginally augmented from the fast.ai Git repository, and made interactive in Colab by Pancham Banerjee
#
# ### Here, we focus on the last part of the lecture:: on fine-tuning large language models
#
# ### The Colab notebook code associated with Jeremy Howard's wonderful lecture
#
# ### Lecture link::: (https://www.youtube.com/watch?v=jkrNMKz9pWU&ab_channel=JeremyHoward).
#
# The original notebook may be found here: https://github.com/fastai/lm-hackers/blob/main/lm-hackers.ipynb
#
# The fast.ai Deep learning course that Howard recommends at the beginning:: https://course.fast.ai/

# %%
# !pip install datasets accelerate -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 493.7/493.7 kB 9.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 258.1/258.1 kB 33.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 15.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 18.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.0/302.0 kB 31.4 MB/s eta 0:00:00

# %% [markdown]
# ### Using the following know_sql dataset to finetune:: https://huggingface.co/datasets/knowrohit07/know_sql

# %%
import datasets
ds = datasets.load_dataset('knowrohit07/know_sql', revision='f33425d13f9e8aab1b46fa945326e9356d6d5726')
# Out:
# ...
# Extracting data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Generating train split: 0 examples [00:00, ? examples/s]

# %%
ds
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['answer', 'question', 'context'],
#         num_rows: 78562
#     })
# })

# %%
trn = ds['train']
trn[3]
# Out:
# {'answer': "SELECT Hosts FROM farm_competition WHERE Theme <> 'Aliens'",
#  'question': 'What are the hosts of competitions whose theme is not "Aliens"?',
#  'context': 'CREATE TABLE farm_competition (Hosts VARCHAR, Theme VARCHAR)'}

# %%
# !git clone https://github.com/OpenAccess-AI-Collective/axolotl
# Out:
# Cloning into 'axolotl'...
# remote: Enumerating objects: 7365, done.
# remote: Counting objects: 100% (570/570), done.
# remote: Compressing objects: 100% (241/241), done.
# remote: Total 7365 (delta 330), reused 472 (delta 268), pack-reused 6795
# Receiving objects: 100% (7365/7365), 2.62 MiB | 34.85 MiB/s, done.
# Resolving deltas: 100% (4685/4685), done.

# %% [markdown]
# ### Modify the qlora.yml file and run it using axolotl

# %% [markdown]
# ### Copy qlora.yml to sql.yml,  change the path and type
